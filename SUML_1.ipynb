# %% [markdown]
# <a href="https://colab.research.google.com/github/pjatk-suml2023/suml-lab-ZG3Z/blob/main/SUML_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from google.colab import drive

# %% [markdown]
# # ex. 1

# %%
df = pd.read_csv('DSP_4.csv', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   objawy   60 non-null     int64
#  1   wiek     55 non-null     float64
#  2   choroby  60 non-null     int64
#  3   wzrost   55 non-null     float64
#  4   leki     60 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 2.5 KB

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 3)

# %%
display(df)
# Out:
#     objawy  wiek  choroby  wzrost  leki
# 0      1     NaN     0      170.0    2
# 1      1    65.0     0        NaN    3
# 2      1    55.0     0      182.0    4
# 3      1    44.0     0      187.0    3
# 4      1    77.0     0      165.0    2
# ..     ...   ...      ...     ...   ...
# 55     5    25.0     0      199.0    1
# 56     5    33.0     1      200.0    2
# 57     5    42.0     2      187.0    3
# 58     5    32.0     0      168.0    4
# 59     5    34.0     1      187.0    3
#
# [60 rows x 5 columns]

# %% [markdown]
# # ex. 2

# %%
df.isnull().sum()
# Out:
# objawy     0
# wiek       5
# choroby    0
# wzrost     5
# leki       0
# dtype: int64

# %%
df_3 = df.fillna(df.median())
df_4 = df.fillna(0)

# %%
display(df_3)
print("Median age:", df_3.wiek.median())
print("Median height:", df_3.wzrost.median())
# Out:
#     objawy  wiek  choroby  wzrost  leki
# 0      1    43.0     0      170.0    2
# 1      1    65.0     0      187.0    3
# 2      1    55.0     0      182.0    4
# 3      1    44.0     0      187.0    3
# 4      1    77.0     0      165.0    2
# ..     ...   ...      ...     ...   ...
# 55     5    25.0     0      199.0    1
# 56     5    33.0     1      200.0    2
# 57     5    42.0     2      187.0    3
# 58     5    32.0     0      168.0    4
# 59     5    34.0     1      187.0    3
#
# [60 rows x 5 columns]
# Median age: 43.0
# Median height: 187.0

# %%
display(df_4)
# Out:
#     objawy  wiek  choroby  wzrost  leki
# 0      1     0.0     0      170.0    2
# 1      1    65.0     0        0.0    3
# 2      1    55.0     0      182.0    4
# 3      1    44.0     0      187.0    3
# 4      1    77.0     0      165.0    2
# ..     ...   ...      ...     ...   ...
# 55     5    25.0     0      199.0    1
# 56     5    33.0     1      200.0    2
# 57     5    42.0     2      187.0    3
# 58     5    32.0     0      168.0    4
# 59     5    34.0     1      187.0    3
#
# [60 rows x 5 columns]

# %%
print("Total missing values in df_3:", df_3.isnull().sum().sum())
print("Total missing values in df_4:",df_4.isnull().sum().sum())
# Out:
# Total missing values in df_3: 0
# Total missing values in df_4: 0

# %% [markdown]
# # ex. 3

# %%
df_5 = pd.read_csv('DSP_5.csv', sep=';')

# %%
df_5
# Out:
#          model          mpg  cyl  disp    hp    drat   wt    qsec   vs  am  \
# 0           Mazda RX4  21.0   6   160.0  110.0  3.90  2.620  16.46   0   1
# 1       Mazda RX4 Wag  21.0   6   160.0  110.0  3.90  2.875  17.02   0   1
# 2          Datsun 710  22.8   4   108.0   93.0  3.85  2.320  18.61   1   1
# 3      Hornet 4 Drive  21.4   6   258.0  110.0  3.08  3.215  19.44   1   0
# 4   Hornet Sportabout  18.7   8   360.0  175.0  3.15    NaN  17.02   0   0
# ..                ...   ...  ...    ...    ...   ...    ...    ...  ..  ..
# 27       Lotus Europa  30.4   4    95.1  113.0  3.77  1.513  16.90   1   1
# 28     Ford Pantera L  15.8   8   351.0  264.0  4.22  3.170  14.50   0   1
# 29       Ferrari Dino  19.7   6   145.0  175.0  3.62  2.770  15.50   0   1
# 30      Maserati Bora  15.0   8   301.0  335.0  3.54  3.570  14.60   0   1
# 31         Volvo 142E  21.4   4   121.0  109.0  4.11  2.780  18.60   1   1
#
#     gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# ...

# %%
df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      31 non-null     float64
#  5   drat    32 non-null     float64
#  6   wt      30 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
df_5.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       1
# drat     0
# wt       2
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df_5.fillna(df_5.mean(numeric_only=True), inplace=True)

# %%
print("Total missing values in df_5:", df_5.isnull().sum().sum())
# Out:
# Total missing values in df_5: 0

# %%
print("Mean hp:", round(df_5['hp'].mean(), 2))
print("Variance hp:", round(df_5['hp'].var(), 2))
print("Range hp:", round(df_5['hp'].max() - df_5['hp'].min(), 2))
# Out:
# Mean hp: 143.52
# Variance hp: 4379.02
# Range hp: 283.0

# %%
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(df_5.corr(numeric_only=True), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation matrix', fontdict={"fontsize":14}, pad=12);

# %% [markdown]
# # ex. 4

# %%
df_8 = pd.read_csv("DSP_8.csv", sep=',', decimal=',')

# %%
df_8
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0    40    M       ATA         140         289          0       Normal
# 1    49    F       NAP         160         180          0       Normal
# 2    37    M       ATA         130         283          0           ST
# 3    48    F       ASY         138         214          0       Normal
# 4    54    M       NAP         150         195          0       Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913  45    M        TA         110         264          0       Normal
# 914  68    M       ASY         144         193          1       Normal
# 915  57    M       ASY         130         131          0       Normal
# 916  57    F       ATA         130         236          0          LVH
# 917  38    M       NAP         138         175          0       Normal
#
#      MaxHR ExerciseAngina Oldpeak ST_Slope  HeartDisease
# 0     172         N            0      Up          0
# ...

# %%
df_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    object
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: int64(6), object(6)
# memory usage: 86.2+ KB

# %%
num_columns = len(df_8.columns)
column_names = df_8.columns.tolist()
print(f"a) Number of columns: {num_columns}\n   Column names: {column_names}")
# Out:
# a) Number of columns: 12
#    Column names: ['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope', 'HeartDisease']

# %%
num_rows = len(df_8)
print("b) Number of rows:", num_rows)
# Out:
# b) Number of rows: 918

# %%
missing_values = df_8.isnull().sum().sum()
print("c) Total missing values:", missing_values)
# Out:
# c) Total missing values: 0

# %%
mean_age_female = df_8[df_8['Sex'] == 'F']['Age'].mean()
std_age_female = df_8[df_8['Sex'] == 'F']['Age'].std()
mean_age_male = df_8[df_8['Sex'] == 'M']['Age'].mean()
std_age_male = df_8[df_8['Sex'] == 'M']['Age'].std()
print(f"d) Mean age for females: {mean_age_female:.2f}, Standard deviation of age for females: {std_age_female:.2f}")
print(f"   Mean age for males: {mean_age_male:.2f}, Standard deviation of age for males: {std_age_male:.2f}")
# Out:
# d) Mean age for females: 52.49, Standard deviation of age for females: 9.52
#    Mean age for males: 53.78, Standard deviation of age for males: 9.40

# %%
percentage_male = (df_8['Sex'] == 'M').sum() / num_rows * 100
print(f"e) Percentage of males: {percentage_male:.2f}%")
# Out:
# e) Percentage of males: 78.98%

# %%
num_female_45to50 = ((df_8['Sex'] == 'F') & (df_8['Age'] >= 45) & (df_8['Age'] <= 50)).sum()
print("f) Number of females between the ages of 45 and 50:", num_female_45to50)
# Out:
# f) Number of females between the ages of 45 and 50: 36

# %%
filtered_df = df_8[df_8['RestingECG'] == 'Normal']
print('g)\n')
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(filtered_df.corr(numeric_only=True), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Matrix for Individuals with Normal Resting ECG', fontdict={"fontsize":14}, pad=12);
# Out:
# g)
